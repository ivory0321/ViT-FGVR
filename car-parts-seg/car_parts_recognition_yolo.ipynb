# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.3.223 🚀 Python-3.10.12 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Setup complete ✅ (12 CPUs, 47.0 GB RAM, 136.0/1006.9 GB disk)

# %%
from ultralytics import YOLO

model = YOLO("yolo11n-seg.pt")
results = model.train(data="carparts-seg.yaml", 
                      epochs=15, 
                      imgsz=640, 
                      batch=32, 
                      workers=20)
# Out:
# New https://pypi.org/project/ultralytics/8.3.234 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.223 🚀 Python-3.10.12 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %% [markdown]
# # inference

# %%
from ultralytics import YOLO
best_model_path = "runs/segment/train-canny-50-100/weights/best.pt"
best_model = YOLO(best_model_path)
predictions = best_model.predict("../data/Stanford_Cars_Edge/test/Acura RL Sedan 2012/000123.png",save=True,conf=0.05)
# Out:
# image 1/1 /mnt/d/Desktop/2025 Fall/CS566/Project/car-parts-seg/../data/Stanford_Cars_Edge/test/Acura RL Sedan 2012/000123.png: 256x640 1 back_bumper, 2 back_left_doors, 1 back_right_door, 2 back_right_lights, 1 front_left_door, 4 wheels, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 9.1ms postprocess per image at shape (1, 3, 256, 640)
# Results saved to /mnt/d/Desktop/2025 Fall/CS566/Project/car-parts-seg/runs/segment/predict3
